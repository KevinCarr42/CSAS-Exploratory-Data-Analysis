# %% [markdown]
# # Sept 24 Coordinators Meeting - Text Extraction & Analysis
# Processing meeting documents through extraction, cleaning, categorization, and summarization.

# %% [markdown]
# ## NOTE:
# this is terrible. it didn't work at all. 0 insights are available in this analysis. ¯\\\_(ツ)\_/¯

# %%
import os
import pandas as pd
from pathlib import Path
import sys
import json

# Setup - change to notebook directory first
# The notebook should be run with working directory as sept_24_coordinators_meeting/
if not os.path.exists('meeting_files'):
    os.chdir('..')
    if not os.path.exists('meeting_files'):
        os.chdir('sept_24_coordinators_meeting')

meeting_folder = 'meeting_files'
data_dir = 'data'
os.makedirs(data_dir, exist_ok=True)

# Import helper functions
sys.path.insert(0, os.getcwd())
from extract_helpers import extract_docx_content, extract_pptx_content
from categorize_helpers import detect_language, normalize_text, categorize_content, detect_themes, THEMES
from summary_helpers import export_summaries, export_theme_analysis
from analysis_helpers import (analyze_patterns, identify_conflicts, identify_high_priority_items,
                               generate_stakeholder_summary, generate_follow_up_actions, export_analysis)

print(f"Working directory: {os.getcwd()}")
print(f"Meeting folder: {os.path.abspath(meeting_folder)}")
print(f"Data directory: {os.path.abspath(data_dir)}")
print("Setup complete. Ready to process meeting documents.")
# Out:
# Working directory: C:\Users\CARRK\Documents\Repositories\dm_apps_root\csas_eda\sept_24_coordinators_meeting
# Meeting folder: C:\Users\CARRK\Documents\Repositories\dm_apps_root\csas_eda\sept_24_coordinators_meeting\meeting_files
# Data directory: C:\Users\CARRK\Documents\Repositories\dm_apps_root\csas_eda\sept_24_coordinators_meeting\data
# Setup complete. Ready to process meeting documents.

# %% [markdown]
# ## Phase 2-3: Extract and Clean Data

# %%
# Extract all documents
all_data = []
for file_name in sorted(os.listdir(meeting_folder)):
    file_path = os.path.join(meeting_folder, file_name)
    if not os.path.isfile(file_path):
        continue

    file_ext = Path(file_path).suffix.lower()
    content = []

    if file_ext == '.docx':
        content = extract_docx_content(file_path)
    elif file_ext == '.pptx':
        content = extract_pptx_content(file_path)

    for item in content:
        all_data.append({
            'source_file': file_name,
            'source_type': file_ext,
            'text': item['text'],
            'element_type': item['element_type'],
            'style': item['style']
        })

df_raw = pd.DataFrame(all_data)
df_raw.insert(0, 'row_id', range(1, len(df_raw) + 1))

print(f"Extracted {len(df_raw)} rows from {df_raw['source_file'].nunique()} documents")
# Out:
# Extracted 862 rows from 12 documents

# %% [markdown]
# ## Phase 3-4: Categorize and Refine

# %%
# Add language detection and categorization
df_clean = df_raw.copy()
df_clean['language'] = df_clean['text'].apply(detect_language)
df_clean['text_normalized'] = df_clean['text'].apply(normalize_text)

# Categorize content
categorization = df_clean['text'].apply(categorize_content)
df_clean['action_categories'] = categorization.apply(lambda x: x['action_categories'])
df_clean['recommendation_categories'] = categorization.apply(lambda x: x['recommendation_categories'])
df_clean['contention_categories'] = categorization.apply(lambda x: x['contention_categories'])

# Add strength scores
df_clean['action_strength'] = df_clean['action_categories'].apply(len)
df_clean['recommendation_strength'] = df_clean['recommendation_categories'].apply(len)
df_clean['contention_strength'] = df_clean['contention_categories'].apply(len)

# Mark document status
df_clean['document_status'] = 'primary'
df_clean.loc[df_clean['source_file'] == 'F2F Meeting Report (near final).docx', 'document_status'] = 'superseded'
df_clean.loc[df_clean['source_file'].isin([
    'CSAS Transformation update.pptx', 
    'CSAS Transformation update-FR.pptx'
]), 'document_status'] = 'primary_translated'

# Create primary dataset (exclude superseded)
df_primary = df_clean[df_clean['document_status'] != 'superseded'].copy()

# Export processed data
df_clean.to_pickle(os.path.join(data_dir, 'meeting_data_refined.pkl'))
df_primary.to_pickle(os.path.join(data_dir, 'meeting_data_primary.pkl'))

print(f"Processed: {len(df_clean)} total rows, {len(df_primary)} primary rows")
# Out:
# Processed: 862 total rows, 689 primary rows

# %% [markdown]
# ## Phase 5: Quality Assessment

# %%
# Quick quality check
qa_metrics = {
    'total_rows': len(df_primary),
    'documents': df_primary['source_file'].nunique(),
    'languages': df_primary['language'].nunique(),
    'action_items': (df_primary['action_strength'] > 0).sum(),
    'recommendations': (df_primary['recommendation_strength'] > 0).sum(),
    'contentions': (df_primary['contention_strength'] > 0).sum(),
    'null_values': df_primary.isnull().sum().sum(),
    'language_detection_rate': f"{(df_primary['language'] != 'unknown').sum() / len(df_primary) * 100:.1f}%"
}

print("Quality Assessment:")
for key, value in qa_metrics.items():
    print(f"  {key}: {value}")
# Out:
# Quality Assessment:
#   total_rows: 689
#   documents: 11
#   languages: 20
#   action_items: 86
#   recommendations: 130
#   contentions: 91
#   null_values: 0
#   language_detection_rate: 95.6%

# %% [markdown]
# ## Phase 6: Final Summarization

# %%
# Load primary dataset and add themes
df_summary = pd.read_pickle(os.path.join(data_dir, 'meeting_data_primary.pkl'))
df_summary['themes'] = df_summary['text'].apply(detect_themes)

# Export summaries
action_summary, recommendations_summary, contentions_summary = export_summaries(df_summary, data_dir)
theme_counts = export_theme_analysis(df_summary, THEMES, data_dir)

print(f"Summary exported:")
print(f"  Action items: {action_summary['total_action_items']}")
print(f"  Recommendations: {recommendations_summary['total_recommendations']}")
print(f"  Contentions: {contentions_summary['total_contentions']}")
print(f"  Themes: {len(theme_counts)}")
# Out:
# Summary exported:
#   Action items: 17
#   Recommendations: 19
#   Contentions: 2
#   Themes: 6

# %%
# Phase 7: Run analysis and generate all required JSON files
df_analysis = pd.read_pickle(os.path.join(data_dir, 'meeting_data_summary.pkl')) if os.path.exists(os.path.join(data_dir, 'meeting_data_summary.pkl')) else df_summary

# Run all analysis
patterns = analyze_patterns(df_analysis)
conflicts_df = identify_conflicts(df_analysis)
high_priority = identify_high_priority_items(df_analysis)
stakeholder_summary = generate_stakeholder_summary(df_analysis)
follow_up = generate_follow_up_actions(df_analysis)

# Export all Phase 7 results
export_analysis(patterns, conflicts_df, high_priority, stakeholder_summary, follow_up, data_dir)

print("Phase 7 Analysis Complete:")
print(f"  Patterns analyzed")
print(f"  Conflicts identified: {len(conflicts_df)}")
print(f"  High priority items: {len(high_priority['action_items']) + len(high_priority['recommendations']) + len(high_priority['contentions'])}")
print(f"  Stakeholder summary: {len(stakeholder_summary)} themes")
print(f"  Follow-up actions: {len(follow_up)} categories")
# Out:
# Phase 7 Analysis Complete:
#   Patterns analyzed
#   Conflicts identified: 0
#   High priority items: 5
#   Stakeholder summary: 6 themes
#   Follow-up actions: 103 categories

# %% [markdown]
# ### Finding 1: High Priority Action Items

# %%
# Load high priority action items
with open(os.path.join(data_dir, 'phase7_high_priority.json'), 'r') as f:
    high_priority_data = json.load(f)

# Convert to DataFrame for display
if high_priority_data['action_items']:
    action_items_df = pd.DataFrame(high_priority_data['action_items'])
    action_items_df = action_items_df[['source_file', 'text', 'action_strength', 'action_categories']].rename(columns={
        'source_file': 'Source File',
        'text': 'Action Item',
        'action_strength': 'Strength',
        'action_categories': 'Categories'
    })
    
    print(f'HIGH PRIORITY ACTION ITEMS ({len(action_items_df)} identified)\n')
    for _, row in action_items_df[['Action Item']].iterrows():
        print(row.values[0])
        print()
else:
    print('HIGH PRIORITY ACTION ITEMS\nNone identified')
# Out:
# HIGH PRIORITY ACTION ITEMS (4 identified)
#
# ACTION: CSAS Coordinators to identify regional rep for Phase 1 Task Team; Task Team to identify process to ensure efficiencies are realized; once Phase 1 is implemented, Task Team will consider options for Phase 2.
#
# Issue: Timelines from meeting to publication of document can be lengthy. Some steps can be compressed to reduce timelines while many cannot.  The readiness of the document can influence timelines at many steps.  For example, poorly prepared materials can result in delays including challenges reaching consensus (e.g. not all documentation/analyses presented), and to follow-up meetings or emails to conclude the meeting and/or to complete the SAR, as well as more time and effort to complete the documents. A working paper should not require major revisions, apart from changes requested during the peer-review meeting.
#
# Allow time for the Steering Committee (SC) to meet their responsibility (CSAS Guideline on the Role and Responsibilities of DFO Science Peer Review Steering Committees ) to go over working paper(s) in advance of the meeting to ensure the objectives of the Terms of Reference (ToR) are met.  The Steering Committee should receive a draft three to four weeks before the meeting so that they can undertake an initial check that the document is complete and clearly addresses the objectives in the TOR. The SC should be allowed 3-5 days for this step.
#
#  Consider timelines and ability to complete the process within the decision-making timeline;
#  Determine level of complexity and rigor needed in the peer-review process (i.e., Globe and Mail check); ensure the right level of rigor and critic was applied;
#  Determine if existing advice is published (e.g., framework) that will allow for efficiencies in the process and publication;
#  Determine and consider the audience (e.g., include figure or not, tables, figures);

# %% [markdown]
# ### Finding 2: Top Recommendations

# %%
# Load high priority recommendations
if high_priority_data['recommendations']:
    recommendations_df = pd.DataFrame(high_priority_data['recommendations'])
    recommendations_df = recommendations_df[['source_file', 'text', 'recommendation_strength', 'recommendation_categories']].rename(columns={
        'source_file': 'Source File',
        'text': 'Recommendation',
        'recommendation_strength': 'Strength',
        'recommendation_categories': 'Categories'
    })
    print(f'TOP RECOMMENDATIONS ({len(recommendations_df)} identified)\n')
    for _, row in recommendations_df[['Recommendation']].iterrows():
        print(row.values[0])
        print()
else:
    print('TOP RECOMMENDATIONS\nNone identified')
# Out:
# TOP RECOMMENDATIONS (1 identified)
#
# ACTION: CSAS Coordinators to identify regional rep for Phase 1 Task Team; Task Team to identify process to ensure efficiencies are realized; once Phase 1 is implemented, Task Team will consider options for Phase 2.

# %% [markdown]
# ### Finding 3: Critical Issues/Contentions

# %%
# Load high priority contentions
if high_priority_data['contentions']:
    contentions_df = pd.DataFrame(high_priority_data['contentions'])
    contentions_df = contentions_df[['source_file', 'text', 'contention_strength', 'contention_categories']].rename(columns={
        'source_file': 'Source File',
        'text': 'Issue/Contention',
        'contention_strength': 'Strength',
        'contention_categories': 'Categories'
    })
    print(f'CRITICAL ISSUES/CONTENTIONS ({len(contentions_df)} identified)\n')
    print(contentions_df.to_string(index=False))
else:
    print('CRITICAL ISSUES/CONTENTIONS')
    print(f'\nGood news: No critical contentions identified')
# Out:
# CRITICAL ISSUES/CONTENTIONS
#
# Good news: No critical contentions identified

# %% [markdown]
# ### Finding 4: Theme-Based Stakeholder Summary

# %%
# Load stakeholder summary
with open(os.path.join(data_dir, 'phase7_stakeholder_summary.json'), 'r') as f:
    stakeholder_data = json.load(f)

# Convert to DataFrame for display
theme_summary_list = []
for theme, data in stakeholder_data.items():
    theme_summary_list.append({
        'Theme': theme,
        'Total Items': data['total_items'],
        'Actions': data['action_items'],
        'Recommendations': data['recommendations'],
        'Issues': data['issues']
    })

theme_summary_df = pd.DataFrame(theme_summary_list).sort_values('Total Items', ascending=False)
print(f'THEME-BASED SUMMARY ({len(theme_summary_df)} themes)\n')
display(theme_summary_df)
# Out:
# THEME-BASED SUMMARY (6 themes)
#                     Theme  Total Items Actions Recommendations Issues
# 0                 General          403      23               6     33
# 2            Publications          216      57              83     45
# 1  Process/Best Practices          102      22              98     31
# 4          Transformation           51       7              13      9
# 5      Web/Centralization           21       9              10      5
# 3       Survival/Exercise            9       2               1      0

# %% [markdown]
# ### Finding 5: Action Items Distribution

# %%
# Load patterns
with open(os.path.join(data_dir, 'phase7_patterns.json'), 'r') as f:
    patterns_data = json.load(f)

# Action items by source file
action_by_source = patterns_data['action_item_distribution']['by_source_file']
action_source_df = pd.DataFrame(list(action_by_source.items()), columns=['Source File', 'Action Items Count'])
action_source_df = action_source_df.sort_values('Action Items Count', ascending=False)

print('ACTION ITEMS DISTRIBUTION BY SOURCE FILE\n')
display(action_source_df)

# Action items by theme
print('\n\nACTION ITEMS DISTRIBUTION BY THEME\n')
action_by_theme = patterns_data['action_item_distribution']['by_theme']
action_theme_df = pd.DataFrame(list(action_by_theme.items()), columns=['Theme', 'Action Items Count'])
action_theme_df = action_theme_df.sort_values('Action Items Count', ascending=False)
display(action_theme_df)
# Out:
# ACTION ITEMS DISTRIBUTION BY SOURCE FILE
#                                          Source File  Action Items Count
# 6                     F2F Meeting Notes (draft).docx                  41
# 8  Options and best practices for timely publicat...                  28
# 2                    CSAS Transformation update.pptx                  14
# 3         Centralization of web and publication.docx                   7
# 9                            Process vs Product.pptx                   6
# 0                             CSAS Publications.pptx                   4
# 1                 CSAS Transformation update-FR.pptx                   3
# 4                       Coordinators F2F Agenda.docx                   2
# 5                              F2F Action Items.docx                   1
# 7  F2F Meeting Report (near final)_TG_FR_LS_Final...                   1
# ACTION ITEMS DISTRIBUTION BY THEME
#                     Theme  Action Items Count
# 2            Publications                  74
# 1  Process/Best Practices                  31
# 0                 General                  25
# 4          Transformation                  11
# 5      Web/Centralization                  10
# 3       Survival/Exercise                   3

# %% [markdown]
# ### Finding 6: Follow-Up Actions & Recommendations

# %%
# Load follow-up actions
with open(os.path.join(data_dir, 'phase7_follow_up_actions.json'), 'r') as f:
    follow_up_data = json.load(f)

# Convert to DataFrame
follow_up_df = pd.DataFrame(follow_up_data)
follow_up_df = follow_up_df[['type', 'count', 'description']].rename(columns={
    'type': 'Follow-Up Category',
    'count': 'Item Count',
    'description': 'Description'
})

print(f'RECOMMENDED FOLLOW-UP ACTIONS ({len(follow_up_df)} identified)\n')
pd.set_option('display.max_rows', 120)
display(follow_up_df)
# Out:
# RECOMMENDED FOLLOW-UP ACTIONS (103 identified)
#                            Follow-Up Category Item Count  \
# 0                       High Priority Actions          4
# 1    Process/Best Practices - High Contention         31
# 2    Process/Best Practices - High Contention         31
# 3    Process/Best Practices - High Contention         31
# 4    Process/Best Practices - High Contention         31
# 5    Process/Best Practices - High Contention         31
# 6    Process/Best Practices - High Contention         31
# 7    Process/Best Practices - High Contention         31
# 8    Process/Best Practices - High Contention         31
# 9    Process/Best Practices - High Contention         31
# 10   Process/Best Practices - High Contention         31
# 11   Process/Best Practices - High Contention         31
# 12   Process/Best Practices - High Contention         31
# 13   Process/Best Practices - High Contention         31
# 14   Process/Best Practices - High Contention         31
# 15   Process/Best Practices - High Contention         31
# 16   Process/Best Practices - High Contention         31
# 17   Process/Best Practices - High Contention         31
# 18   Process/Best Practices - High Contention         31
# 19   Process/Best Practices - High Contention         31
# 20   Process/Best Practices - High Contention         31
# 21   Process/Best Practices - High Contention         31
# 22   Process/Best Practices - High Contention         31
# 23   Process/Best Practices - High Contention         31
# 24   Process/Best Practices - High Contention         31
# 25   Process/Best Practices - High Contention         31
# 26   Process/Best Practices - High Contention         31
# 27   Process/Best Practices - High Contention         31
# 28   Process/Best Practices - High Contention         31
# 29   Process/Best Practices - High Contention         31
# 30   Process/Best Practices - High Contention         31
# 31   Process/Best Practices - High Contention         31
# 32   Process/Best Practices - High Contention         31
# 33   Process/Best Practices - High Contention         31
# 34   Process/Best Practices - High Contention         31
# 35   Process/Best Practices - High Contention         31
# 36   Process/Best Practices - High Contention         31
# 37   Process/Best Practices - High Contention         31
# 38   Process/Best Practices - High Contention         31
# 39   Process/Best Practices - High Contention         31
# 40   Process/Best Practices - High Contention         31
# 41   Process/Best Practices - High Contention         31
# 42   Process/Best Practices - High Contention         31
# 43   Process/Best Practices - High Contention         31
# 44   Process/Best Practices - High Contention         31
# 45   Process/Best Practices - High Contention         31
# 46   Process/Best Practices - High Contention         31
# 47   Process/Best Practices - High Contention         31
# 48   Process/Best Practices - High Contention         31
# 49   Process/Best Practices - High Contention         31
# 50   Process/Best Practices - High Contention         31
# 51   Process/Best Practices - High Contention         31
# 52   Process/Best Practices - High Contention         31
# 53   Process/Best Practices - High Contention         31
# 54   Process/Best Practices - High Contention         31
# 55   Process/Best Practices - High Contention         31
# 56   Process/Best Practices - High Contention         31
# 57   Process/Best Practices - High Contention         31
# 58   Process/Best Practices - High Contention         31
# 59   Process/Best Practices - High Contention         31
# 60   Process/Best Practices - High Contention         31
# 61   Process/Best Practices - High Contention         31
# 62   Process/Best Practices - High Contention         31
# 63   Process/Best Practices - High Contention         31
# 64   Process/Best Practices - High Contention         31
# 65   Process/Best Practices - High Contention         31
# 66   Process/Best Practices - High Contention         31
# 67   Process/Best Practices - High Contention         31
# 68   Process/Best Practices - High Contention         31
# 69   Process/Best Practices - High Contention         31
# 70   Process/Best Practices - High Contention         31
# 71   Process/Best Practices - High Contention         31
# 72   Process/Best Practices - High Contention         31
# 73   Process/Best Practices - High Contention         31
# 74   Process/Best Practices - High Contention         31
# 75   Process/Best Practices - High Contention         31
# 76   Process/Best Practices - High Contention         31
# 77   Process/Best Practices - High Contention         31
# 78   Process/Best Practices - High Contention         31
# 79   Process/Best Practices - High Contention         31
# 80   Process/Best Practices - High Contention         31
# 81   Process/Best Practices - High Contention         31
# 82   Process/Best Practices - High Contention         31
# 83   Process/Best Practices - High Contention         31
# 84   Process/Best Practices - High Contention         31
# 85   Process/Best Practices - High Contention         31
# 86   Process/Best Practices - High Contention         31
# 87   Process/Best Practices - High Contention         31
# 88   Process/Best Practices - High Contention         31
# 89   Process/Best Practices - High Contention         31
# 90   Process/Best Practices - High Contention         31
# 91   Process/Best Practices - High Contention         31
# 92   Process/Best Practices - High Contention         31
# 93   Process/Best Practices - High Contention         31
# 94   Process/Best Practices - High Contention         31
# 95   Process/Best Practices - High Contention         31
# 96   Process/Best Practices - High Contention         31
# 97   Process/Best Practices - High Contention         31
# 98   Process/Best Practices - High Contention         31
# 99   Process/Best Practices - High Contention         31
# 100  Process/Best Practices - High Contention         31
# 101  Process/Best Practices - High Contention         31
# 102  Process/Best Practices - High Contention         31
#
#                                            Description
# 0    Multiple strong action signals requiring immed...
# 1    30% of Process/Best Practices content flagged ...
# 2    30% of Process/Best Practices content flagged ...
# 3    30% of Process/Best Practices content flagged ...
# 4    30% of Process/Best Practices content flagged ...
# 5    30% of Process/Best Practices content flagged ...
# 6    30% of Process/Best Practices content flagged ...
# 7    30% of Process/Best Practices content flagged ...
# 8    30% of Process/Best Practices content flagged ...
# 9    30% of Process/Best Practices content flagged ...
# 10   30% of Process/Best Practices content flagged ...
# 11   30% of Process/Best Practices content flagged ...
# 12   30% of Process/Best Practices content flagged ...
# 13   30% of Process/Best Practices content flagged ...
# 14   30% of Process/Best Practices content flagged ...
# 15   30% of Process/Best Practices content flagged ...
# 16   30% of Process/Best Practices content flagged ...
# 17   30% of Process/Best Practices content flagged ...
# 18   30% of Process/Best Practices content flagged ...
# 19   30% of Process/Best Practices content flagged ...
# 20   30% of Process/Best Practices content flagged ...
# 21   30% of Process/Best Practices content flagged ...
# 22   30% of Process/Best Practices content flagged ...
# 23   30% of Process/Best Practices content flagged ...
# 24   30% of Process/Best Practices content flagged ...
# 25   30% of Process/Best Practices content flagged ...
# 26   30% of Process/Best Practices content flagged ...
# 27   30% of Process/Best Practices content flagged ...
# 28   30% of Process/Best Practices content flagged ...
# 29   30% of Process/Best Practices content flagged ...
# 30   30% of Process/Best Practices content flagged ...
# 31   30% of Process/Best Practices content flagged ...
# 32   30% of Process/Best Practices content flagged ...
# 33   30% of Process/Best Practices content flagged ...
# 34   30% of Process/Best Practices content flagged ...
# 35   30% of Process/Best Practices content flagged ...
# 36   30% of Process/Best Practices content flagged ...
# 37   30% of Process/Best Practices content flagged ...
# 38   30% of Process/Best Practices content flagged ...
# 39   30% of Process/Best Practices content flagged ...
# 40   30% of Process/Best Practices content flagged ...
# 41   30% of Process/Best Practices content flagged ...
# 42   30% of Process/Best Practices content flagged ...
# 43   30% of Process/Best Practices content flagged ...
# 44   30% of Process/Best Practices content flagged ...
# 45   30% of Process/Best Practices content flagged ...
# 46   30% of Process/Best Practices content flagged ...
# 47   30% of Process/Best Practices content flagged ...
# 48   30% of Process/Best Practices content flagged ...
# 49   30% of Process/Best Practices content flagged ...
# 50   30% of Process/Best Practices content flagged ...
# 51   30% of Process/Best Practices content flagged ...
# 52   30% of Process/Best Practices content flagged ...
# 53   30% of Process/Best Practices content flagged ...
# 54   30% of Process/Best Practices content flagged ...
# 55   30% of Process/Best Practices content flagged ...
# 56   30% of Process/Best Practices content flagged ...
# 57   30% of Process/Best Practices content flagged ...
# 58   30% of Process/Best Practices content flagged ...
# 59   30% of Process/Best Practices content flagged ...
# 60   30% of Process/Best Practices content flagged ...
# 61   30% of Process/Best Practices content flagged ...
# 62   30% of Process/Best Practices content flagged ...
# 63   30% of Process/Best Practices content flagged ...
# 64   30% of Process/Best Practices content flagged ...
# 65   30% of Process/Best Practices content flagged ...
# 66   30% of Process/Best Practices content flagged ...
# 67   30% of Process/Best Practices content flagged ...
# 68   30% of Process/Best Practices content flagged ...
# 69   30% of Process/Best Practices content flagged ...
# 70   30% of Process/Best Practices content flagged ...
# 71   30% of Process/Best Practices content flagged ...
# 72   30% of Process/Best Practices content flagged ...
# 73   30% of Process/Best Practices content flagged ...
# 74   30% of Process/Best Practices content flagged ...
# 75   30% of Process/Best Practices content flagged ...
# 76   30% of Process/Best Practices content flagged ...
# 77   30% of Process/Best Practices content flagged ...
# 78   30% of Process/Best Practices content flagged ...
# 79   30% of Process/Best Practices content flagged ...
# 80   30% of Process/Best Practices content flagged ...
# 81   30% of Process/Best Practices content flagged ...
# 82   30% of Process/Best Practices content flagged ...
# 83   30% of Process/Best Practices content flagged ...
# 84   30% of Process/Best Practices content flagged ...
# 85   30% of Process/Best Practices content flagged ...
# 86   30% of Process/Best Practices content flagged ...
# 87   30% of Process/Best Practices content flagged ...
# 88   30% of Process/Best Practices content flagged ...
# 89   30% of Process/Best Practices content flagged ...
# 90   30% of Process/Best Practices content flagged ...
# 91   30% of Process/Best Practices content flagged ...
# 92   30% of Process/Best Practices content flagged ...
# 93   30% of Process/Best Practices content flagged ...
# 94   30% of Process/Best Practices content flagged ...
# 95   30% of Process/Best Practices content flagged ...
# 96   30% of Process/Best Practices content flagged ...
# 97   30% of Process/Best Practices content flagged ...
# 98   30% of Process/Best Practices content flagged ...
# 99   30% of Process/Best Practices content flagged ...
# 100  30% of Process/Best Practices content flagged ...
# 101  30% of Process/Best Practices content flagged ...
# 102  30% of Process/Best Practices content flagged ...

# %% [markdown]
# ### Finding 7: Conflict Analysis

# %%
# Load conflicts
with open(os.path.join(data_dir, 'phase7_conflicts.json'), 'r') as f:
    conflicts_data = json.load(f)

conflicts_count = conflicts_data['total_conflicts']

if conflicts_count > 0:
    conflicts_df = pd.DataFrame(conflicts_data['conflicts'])
    conflicts_df = conflicts_df[['source_file', 'text', 'action_categories', 'contention_categories']].rename(columns={
        'source_file': 'Source File',
        'text': 'Conflicting Item',
        'action_categories': 'Action Signals',
        'contention_categories': 'Contention Signals'
    })
    print(f'CONFLICT ANALYSIS ({conflicts_count} items with conflicting signals)\n')
    print(conflicts_df.to_string(index=False))
else:
    print('CONFLICT ANALYSIS')
    print(f'\nGood news: No significant conflicts detected ({conflicts_count} items with both action and contention signals)')
# Out:
# CONFLICT ANALYSIS
#
# Good news: No significant conflicts detected (0 items with both action and contention signals)
